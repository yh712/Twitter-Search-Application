# %% [markdown]
# # PostgreSQL

# %%
import psycopg2

# %% [markdown]
# ## Construct the Postgres function for checking connection, creating tables, deleting tables, and creating or dropping indexes

# %%
def pgsql(pgsql_cmd_str, kind):    
    try:
        # Connect to PostgreSQL
        connection = psycopg2.connect(user = "seanhong",
                                      password = "s017003",
                                      host = "localhost",
                                      database = "user_db")
        cursor = connection.cursor()
        if kind == "create":
            cursor.execute(pgsql_cmd_str)
            connection.commit()
            print("PostgreSQL table successfully created\n")
        elif kind == "drop":
            cursor.execute(pgsql_cmd_str)
            connection.commit()
            print("PostgreSQL table successfully dropped\n")
        elif kind == "connect":
            cursor.execute(pgsql_cmd_str)
            print("You are connected to - ", cursor.fetchone(),"\n")
        elif kind == "index":
            cursor.execute(pgsql_cmd_str)
            connection.commit()
            print("Indexes created/dropped successfully in PostgreSQL\n")
        else:
            print("Type the wrong kind of command. Only four commands are available: create, drop, connect, index")

    except (Exception, psycopg2.DatabaseError) as error :
        print ("Error while executing PostgreSQL commands:", error)
    finally:
        # Close PostgreSQL connection
            if(connection):
                cursor.close()
                connection.close()
                print("PostgreSQL connection is closed")

# %% [markdown]
# ## Test the connection to PostgreSQL database

# %%
pgsql("SELECT version();", "connect")
# Out:
# You are connected to -  ('PostgreSQL 12.2 on x86_64-apple-darwin19.4.0, compiled by Apple clang version 11.0.3 (clang-1103.0.32.59), 64-bit',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Create the table

# %%
# Create table if not exists
pgsql(''' CREATE TABLE IF NOT EXISTS users
              (id BIGINT PRIMARY KEY,
              name TEXT NOT NULL,
              screen_name TEXT NOT NULL,
              protected BOOLEAN NOT NULL,
              verified BOOLEAN NOT NULL,
              followers_count BIGINT NOT NULL,
              friends_count INTEGER NOT NULL,
              listed_count INTEGER NOT NULL,
              favourites_count BIGINT NOT NULL,
              statuses_count BIGINT NOT NULL,
              created_at TEXT NOT NULL
              ); ''', "create")
# Out:
# PostgreSQL table successfully created
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Insert or update data

# %%
# Connect to postgresql
connection = psycopg2.connect(user = "seanhong",
                              password = "s017003",
                              host = "localhost",
                              database = "user_db")
cursor = connection.cursor()
# Define a insert/update object
postgres_insert_one = '''
INSERT INTO 
    users
VALUES
    (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (id)
    DO UPDATE SET
        (name, screen_name, protected, verified, followers_count, friends_count, listed_count, favourites_count, 
        statuses_count, created_at)
        = (EXCLUDED.name, EXCLUDED.screen_name, EXCLUDED.protected, EXCLUDED.verified, EXCLUDED.followers_count, 
        EXCLUDED.friends_count, EXCLUDED.listed_count, EXCLUDED.favourites_count, EXCLUDED.statuses_count, 
        EXCLUDED.created_at);'''    
# Load JSON file into postgresql database
import json
with open("twitter_hang", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            usr_dic = {}
            for key in data['user']:
                if key in ['id','name','screen_name','protected','verified','followers_count','friends_count',
                           'listed_count','favourites_count','statuses_count','created_at']:
                    usr_dic[key] = data['user'][key]            
            # INSERT data into postgre here
            user_to_insert = tuple(usr_dic.values())
            cursor.execute(postgres_insert_one, user_to_insert)
        except:
            continue
connection.commit()
# Close database connection.
if(connection):
    cursor.close()
    connection.close()
    print("Data inserted or updated successfully in user table\n")
    print("PostgreSQL connection is closed")
# Out:
# Data inserted or updated successfully in user table
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Construct the querying function and analytical querying function

# %%
def query_data(pgsql_cmd_str, kind):
    try:
        # Connect to postgresql
        connection = psycopg2.connect(user = "seanhong",
                                      password = "s017003",
                                      host = "localhost",
                                      database = "user_db")
        cursor = connection.cursor()
        if kind == "result":            
            cursor.execute(pgsql_cmd_str)
            record = cursor.fetchall()
            if record == []:
                print("None of the users met the requirement")
            else:
                print("There are %d querying results"%(len(record)), "\n")
            for row in range(len(record)):
                print("NO.%d user"%(row+1))
                print("id :", record[row][0])
                print("name :", record[row][1])
                print("screen_name :", record[row][2])
                print("protected :", record[row][3])
                print("verified :", record[row][4])
                print("followers_count :", record[row][5])
                print("friends_count :", record[row][6])
                print("listed_count :", record[row][7])
                print("favourites_count :", record[row][8])
                print("statuses_count :", record[row][9])
                print("created_at :", record[row][10], "\n")
        elif kind == "analyze":
            cursor.execute(pgsql_cmd_str)
            record = cursor.fetchall()
            for obj in range(len(record)):
                print(record[obj],"\n")
        else:
            print("Type the wrong kind of command. Only two commands are available: result and analyze")
    except (Exception, psycopg2.DatabaseError) as error :
        print ("Error while querying data", error)
    # Close PostgreSQL connection
    finally:
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")

# %% [markdown]
# ## Analyze querying times before indexing

# %% [markdown]
# ### 1. Find the top 3 most followed users as an example

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users ORDER BY followers_count DESC LIMIT 3", "analyze")
# Out:
# ('Limit  (cost=673.09..673.10 rows=3 width=138) (actual time=5.835..5.836 rows=3 loops=1)',)
#
# ('  ->  Sort  (cost=673.09..711.92 rows=15533 width=138) (actual time=5.834..5.835 rows=3 loops=1)',)
#
# ('        Sort Key: followers_count DESC',)
#
# ('        Sort Method: top-N heapsort  Memory: 25kB',)
#
# ('        ->  Seq Scan on users  (cost=0.00..472.33 rows=15533 width=138) (actual time=0.033..4.136 rows=16045 loops=1)',)
#
# ('Planning Time: 0.343 ms',)
#
# ('Execution Time: 5.868 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 2. Find users with numbers of followers more than 100K

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users WHERE followers_count>100000 ORDER BY followers_count DESC", "analyze")
# Out:
# ('Sort  (cost=522.98..523.36 rows=150 width=100) (actual time=2.936..2.947 rows=134 loops=1)',)
#
# ('  Sort Key: followers_count DESC',)
#
# ('  Sort Method: quicksort  Memory: 44kB',)
#
# ('  ->  Seq Scan on users  (cost=0.00..517.56 rows=150 width=100) (actual time=0.011..2.859 rows=134 loops=1)',)
#
# ('        Filter: (followers_count > 100000)',)
#
# ('        Rows Removed by Filter: 15911',)
#
# ('Planning Time: 0.555 ms',)
#
# ('Execution Time: 3.008 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 3. Find the verified user with the smallest number of followers

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users WHERE verified = true ORDER BY followers_count ASC LIMIT 1", "analyze")
# Out:
# ('Limit  (cost=478.76..478.76 rows=1 width=100) (actual time=2.600..2.600 rows=1 loops=1)',)
#
# ('  ->  Sort  (cost=478.76..479.41 rows=261 width=100) (actual time=2.599..2.599 rows=1 loops=1)',)
#
# ('        Sort Key: followers_count',)
#
# ('        Sort Method: top-N heapsort  Memory: 25kB',)
#
# ('        ->  Seq Scan on users  (cost=0.00..477.45 rows=261 width=100) (actual time=0.010..2.529 rows=261 loops=1)',)
#
# ('              Filter: verified',)
#
# ('              Rows Removed by Filter: 15784',)
#
# ('Planning Time: 0.502 ms',)
#
# ('Execution Time: 2.638 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Create indexes for followers_count

# %%
pgsql("CREATE INDEX followers_idx ON users(followers_count)", "index")
# Out:
# Indexes created/dropped successfully in PostgreSQL
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Create multicolumn indexes for followers and verified

# %%
pgsql("CREATE INDEX followers_verified_idx ON users(followers_count, verified)", "index")
# Out:
# Indexes created/dropped successfully in PostgreSQL
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Analyze querying times after indexing

# %% [markdown]
# ### 1. Find the top 3 most followed users as an example

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users ORDER BY followers_count DESC LIMIT 3", "analyze")
# Out:
# ('Limit  (cost=0.29..0.60 rows=3 width=100) (actual time=0.022..0.030 rows=3 loops=1)',)
#
# ('  ->  Index Scan Backward using followers_idx on users  (cost=0.29..1692.81 rows=16045 width=100) (actual time=0.021..0.029 rows=3 loops=1)',)
#
# ('Planning Time: 0.593 ms',)
#
# ('Execution Time: 0.060 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 2. Find users with numbers of followers more than 100K

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users WHERE followers_count>100000 ORDER BY followers_count DESC", "analyze")
# Out:
# ('Sort  (cost=273.69..274.06 rows=150 width=100) (actual time=0.406..0.414 rows=134 loops=1)',)
#
# ('  Sort Key: followers_count DESC',)
#
# ('  Sort Method: quicksort  Memory: 44kB',)
#
# ('  ->  Bitmap Heap Scan on users  (cost=5.45..268.27 rows=150 width=100) (actual time=0.041..0.346 rows=134 loops=1)',)
#
# ('        Recheck Cond: (followers_count > 100000)',)
#
# ('        Heap Blocks: exact=107',)
#
# ('        ->  Bitmap Index Scan on followers_verified_idx  (cost=0.00..5.41 rows=150 width=0) (actual time=0.027..0.027 rows=134 loops=1)',)
#
# ('              Index Cond: (followers_count > 100000)',)
#
# ('Planning Time: 0.633 ms',)
#
# ('Execution Time: 0.477 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 3. Find the verified user with the smallest number of followers

# %%
query_data("EXPLAIN ANALYZE SELECT * FROM users WHERE verified = true ORDER BY followers_count ASC LIMIT 1", "analyze")
# Out:
# ('Limit  (cost=0.29..4.57 rows=1 width=100) (actual time=0.325..0.325 rows=1 loops=1)',)
#
# ('  ->  Index Scan using followers_verified_idx on users  (cost=0.29..1119.17 rows=261 width=100) (actual time=0.324..0.324 rows=1 loops=1)',)
#
# ('        Index Cond: (verified = true)',)
#
# ('Planning Time: 0.539 ms',)
#
# ('Execution Time: 0.355 ms',)
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Query the data

# %% [markdown]
# ### Count the total number of users in the table

# %%
try:
    connection = psycopg2.connect(user = "seanhong",
                                  password = "s017003",
                                  host = "localhost",
                                  database = "user_db")
    cursor = connection.cursor("SELECT COUNT(*) FROM users;")
    pgsql_str = "SELECT COUNT(*) FROM users;"
    cursor.execute(pgsql_str)
    result = cursor.fetchone()
    print("Total number of users in the table:",result[0],"\n")
except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while querying data", error)
finally:
    if(connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Total number of users in the table: 16045
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 1. Find the top 3 most followed users as an example

# %%
query_data("SELECT * FROM users ORDER BY followers_count DESC LIMIT 3", "result")
# Out:
# There are 3 querying results
#
# NO.1 user
# id : 1115874631
# name : CGTN
# screen_name : CGTNOfficial
# protected : False
# verified : True
# followers_count : 14024195
# friends_count : 56
# listed_count : 8412
# favourites_count : 68
# statuses_count : 117674
# created_at : Thu Jan 24 03:18:59 +0000 2013
#
# NO.2 user
# id : 37034483
# name : NDTV
# screen_name : ndtv
# protected : False
# verified : True
# followers_count : 12616711
# friends_count : 15
# listed_count : 12732
# favourites_count : 0
# statuses_count : 704225
# created_at : Fri May 01 20:34:48 +0000 2009
#
# NO.3 user
# id : 16676396
# name : El Universal
# screen_name : El_Universal_Mx
# protected : False
# verified : True
# followers_count : 5512589
# friends_count : 14014
# listed_count : 25234
# favourites_count : 29497
# statuses_count : 864128
# created_at : Fri Oct 10 00:09:06 +0000 2008
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 2. Find users with numbers of followers more than 100K

# %%
query_data("SELECT * FROM users WHERE followers_count>100000 ORDER BY followers_count DESC", "result")
# Out:
# There are 134 querying results
#
# NO.1 user
# id : 1115874631
# name : CGTN
# screen_name : CGTNOfficial
# protected : False
# verified : True
# followers_count : 14024195
# friends_count : 56
# listed_count : 8412
# favourites_count : 68
# statuses_count : 117674
# created_at : Thu Jan 24 03:18:59 +0000 2013
#
# NO.2 user
# id : 37034483
# name : NDTV
# screen_name : ndtv
# protected : False
# verified : True
# followers_count : 12616711
# friends_count : 15
# listed_count : 12732
# favourites_count : 0
# statuses_count : 704225
# created_at : Fri May 01 20:34:48 +0000 2009
#
# NO.3 user
# id : 16676396
# name : El Universal
# screen_name : El_Universal_Mx
# protected : False
# verified : True
# followers_count : 5512589
# friends_count : 14014
# listed_count : 25234
# favourites_count : 29497
# statuses_count : 864128
# created_at : Fri Oct 10 00:09:06 +0000 2008
#
# NO.4 user
# id : 24969337
# name : Milenio
# screen_name : Milenio
# protected : False
# verified : True
# followers_count : 4561261
# friends_count : 157
# listed_count : 16320
# favourites_count : 9
# statuses_count : 862757
# created_at : Tue Mar 17 22:26:38 +0000 2009
#
# NO.5 user
# id : 355989081
# name : ANI
# screen_name : ANI
# protected : False
# verified : True
# followers_count : 3823472
# friends_count : 0
# listed_count : 4653
# favourites_count : 0
# statuses_count : 392510
# created_at : Tue Aug 16 05:23:41 +0000 2011
#
# NO.6 user
# id : 19236074
# name : Caracol Radio
# screen_name : CaracolRadio
# protected : False
# verified : True
# followers_count : 3691793
# friends_count : 157
# listed_count : 9232
# favourites_count : 1019
# statuses_count : 613484
# created_at : Tue Jan 20 13:31:40 +0000 2009
#
# NO.7 user
# id : 330826792
# name : Rappler
# screen_name : rapplerdotcom
# protected : False
# verified : True
# followers_count : 3262632
# friends_count : 404
# listed_count : 4441
# favourites_count : 8088
# statuses_count : 655070
# created_at : Thu Jul 07 06:34:10 +0000 2011
#
# NO.8 user
# id : 3362741
# name : Sopitas
# screen_name : sopitas
# protected : False
# verified : True
# followers_count : 3129741
# friends_count : 3300
# listed_count : 6717
# favourites_count : 4799
# statuses_count : 195939
# created_at : Tue Apr 03 21:18:19 +0000 2007
#
# NO.9 user
# id : 461841349
# name : Zee News
# screen_name : ZeeNews
# protected : False
# verified : True
# followers_count : 2988602
# friends_count : 27
# listed_count : 1302
# favourites_count : 4
# statuses_count : 226657
# created_at : Thu Jan 12 07:52:31 +0000 2012
#
# NO.10 user
# id : 50126679
# name : Telefe Noticias
# screen_name : telefenoticias
# protected : False
# verified : True
# followers_count : 2846917
# friends_count : 82
# listed_count : 3965
# favourites_count : 1880
# statuses_count : 255362
# created_at : Tue Jun 23 22:38:40 +0000 2009
#
# NO.11 user
# id : 5734902
# name : tagesschau
# screen_name : tagesschau
# protected : False
# verified : True
# followers_count : 2703920
# friends_count : 316
# listed_count : 9003
# favourites_count : 3549
# statuses_count : 188417
# created_at : Thu May 03 08:42:42 +0000 2007
#
# NO.12 user
# id : 14982804
# name : Ava DuVernay
# screen_name : ava
# protected : False
# verified : True
# followers_count : 2381479
# friends_count : 13215
# listed_count : 5916
# favourites_count : 175783
# statuses_count : 46011
# created_at : Mon Jun 02 17:53:54 +0000 2008
#
# NO.13 user
# id : 334921284
# name : Félix de Bedout
# screen_name : fdbedout
# protected : False
# verified : True
# followers_count : 2193583
# friends_count : 639
# listed_count : 3088
# favourites_count : 226
# statuses_count : 31544
# created_at : Wed Jul 13 21:40:54 +0000 2011
#
# NO.14 user
# id : 35785401
# name : Univision Noticias
# screen_name : UniNoticias
# protected : False
# verified : True
# followers_count : 2004230
# friends_count : 1877
# listed_count : 7834
# favourites_count : 5568
# statuses_count : 257863
# created_at : Mon Apr 27 16:29:42 +0000 2009
#
# NO.15 user
# id : 104683173
# name : Excélsior
# screen_name : Excelsior
# protected : False
# verified : True
# followers_count : 1882829
# friends_count : 818
# listed_count : 9217
# favourites_count : 3039
# statuses_count : 676882
# created_at : Thu Jan 14 02:23:32 +0000 2010
#
# NO.16 user
# id : 380648579
# name : AFP news agency
# screen_name : AFP
# protected : False
# verified : True
# followers_count : 1845780
# friends_count : 675
# listed_count : 22845
# favourites_count : 2525
# statuses_count : 230915
# created_at : Tue Sep 27 00:35:10 +0000 2011
#
# NO.17 user
# id : 13838562
# name : andyroddick
# screen_name : andyroddick
# protected : False
# verified : True
# followers_count : 1510194
# friends_count : 215
# listed_count : 13705
# favourites_count : 75
# statuses_count : 8123
# created_at : Fri Feb 22 21:23:34 +0000 2008
#
# NO.18 user
# id : 91882544
# name : Dinesh D'Souza
# screen_name : DineshDSouza
# protected : False
# verified : True
# followers_count : 1473110
# friends_count : 5784
# listed_count : 6587
# favourites_count : 647
# statuses_count : 49769
# created_at : Sun Nov 22 22:32:41 +0000 2009
#
# NO.19 user
# id : 58048133
# name : Meganoticias
# screen_name : meganoticiascl
# protected : False
# verified : True
# followers_count : 1396566
# friends_count : 1776
# listed_count : 2537
# favourites_count : 1854
# statuses_count : 526405
# created_at : Sat Jul 18 22:23:30 +0000 2009
#
# NO.20 user
# id : 102094084
# name : PSUV
# screen_name : PartidoPSUV
# protected : False
# verified : True
# followers_count : 1352767
# friends_count : 858
# listed_count : 4972
# favourites_count : 5549
# statuses_count : 476460
# created_at : Tue Jan 05 15:55:21 +0000 2010
#
# NO.21 user
# id : 18166778
# name : Rep. Jim Jordan
# screen_name : Jim_Jordan
# protected : False
# verified : True
# followers_count : 1270720
# friends_count : 4039
# listed_count : 4895
# favourites_count : 1822
# statuses_count : 3953
# created_at : Tue Dec 16 17:20:24 +0000 2008
#
# NO.22 user
# id : 30282704
# name : Mark Sheppard
# screen_name : Mark_Sheppard
# protected : False
# verified : True
# followers_count : 1211081
# friends_count : 1166
# listed_count : 6067
# favourites_count : 27370
# statuses_count : 18047
# created_at : Fri Apr 10 18:47:38 +0000 2009
#
# NO.23 user
# id : 169018518
# name : Amar Ujala
# screen_name : AmarUjalaNews
# protected : False
# verified : True
# followers_count : 1137697
# friends_count : 73
# listed_count : 890
# favourites_count : 1315
# statuses_count : 219071
# created_at : Wed Jul 21 10:04:08 +0000 2010
#
# NO.24 user
# id : 20578408
# name : Gulf News
# screen_name : gulf_news
# protected : False
# verified : True
# followers_count : 1019590
# friends_count : 227
# listed_count : 3500
# favourites_count : 288
# statuses_count : 217941
# created_at : Wed Feb 11 08:21:32 +0000 2009
#
# NO.25 user
# id : 18266688
# name : Tom Fitton
# screen_name : TomFitton
# protected : False
# verified : True
# followers_count : 890351
# friends_count : 3171
# listed_count : 3189
# favourites_count : 528
# statuses_count : 36168
# created_at : Sat Dec 20 14:32:44 +0000 2008
#
# NO.26 user
# id : 22240612
# name : Al Arabiya English
# screen_name : AlArabiya_Eng
# protected : False
# verified : True
# followers_count : 830862
# friends_count : 40
# listed_count : 11175
# favourites_count : 0
# statuses_count : 248777
# created_at : Sat Feb 28 08:31:32 +0000 2009
#
# NO.27 user
# id : 219990061
# name : Fiscalía Colombia
# screen_name : FiscaliaCol
# protected : False
# verified : True
# followers_count : 828307
# friends_count : 737
# listed_count : 1360
# favourites_count : 26
# statuses_count : 31844
# created_at : Fri Nov 26 13:23:47 +0000 2010
#
# NO.28 user
# id : 221378668
# name : Reporte Ya
# screen_name : ReporteYa
# protected : False
# verified : False
# followers_count : 827396
# friends_count : 89782
# listed_count : 2795
# favourites_count : 25359
# statuses_count : 646291
# created_at : Tue Nov 30 14:16:26 +0000 2010
#
# NO.29 user
# id : 19889168
# name : Notimex
# screen_name : Notimex
# protected : False
# verified : True
# followers_count : 819201
# friends_count : 0
# listed_count : 5947
# favourites_count : 1274
# statuses_count : 383217
# created_at : Mon Feb 02 02:23:19 +0000 2009
#
# NO.30 user
# id : 2459609448
# name : Canada
# screen_name : Canada
# protected : False
# verified : True
# followers_count : 771229
# friends_count : 768
# listed_count : 2097
# favourites_count : 2667
# statuses_count : 5893
# created_at : Wed Apr 23 11:48:57 +0000 2014
#
# NO.31 user
# id : 103963822
# name : Milenio Televisión
# screen_name : mileniotv
# protected : False
# verified : True
# followers_count : 751425
# friends_count : 1
# listed_count : 3626
# favourites_count : 0
# statuses_count : 426415
# created_at : Mon Jan 11 20:42:06 +0000 2010
#
# NO.32 user
# id : 55186601
# name : New Straits Times
# screen_name : NST_Online
# protected : False
# verified : False
# followers_count : 706017
# friends_count : 412
# listed_count : 2073
# favourites_count : 824
# statuses_count : 214413
# created_at : Thu Jul 09 09:04:01 +0000 2009
#
# NO.33 user
# id : 182181105
# name : TCS Noticias
# screen_name : tcsnoticias
# protected : False
# verified : True
# followers_count : 700627
# friends_count : 896
# listed_count : 850
# favourites_count : 4054
# statuses_count : 135245
# created_at : Tue Aug 24 00:53:13 +0000 2010
#
# NO.34 user
# id : 15679641
# name : Dallas Morning News
# screen_name : dallasnews
# protected : False
# verified : True
# followers_count : 690798
# friends_count : 734
# listed_count : 6743
# favourites_count : 4455
# statuses_count : 217930
# created_at : Thu Jul 31 19:59:08 +0000 2008
#
# NO.35 user
# id : 257057832
# name : Noticias 4Visión
# screen_name : noticias4vision
# protected : False
# verified : True
# followers_count : 687734
# friends_count : 12642
# listed_count : 885
# favourites_count : 1201
# statuses_count : 136235
# created_at : Thu Feb 24 16:50:19 +0000 2011
#
# NO.36 user
# id : 17537467
# name : Tarek Fatah
# screen_name : TarekFatah
# protected : False
# verified : True
# followers_count : 631393
# friends_count : 2013
# listed_count : 2553
# favourites_count : 568
# statuses_count : 151596
# created_at : Fri Nov 21 14:51:32 +0000 2008
#
# NO.37 user
# id : 1540034828
# name : Mídia NINJA
# screen_name : MidiaNINJA
# protected : False
# verified : True
# followers_count : 627533
# friends_count : 2355
# listed_count : 2194
# favourites_count : 5048
# statuses_count : 56528
# created_at : Sun Jun 23 03:26:00 +0000 2013
#
# NO.38 user
# id : 326849708
# name : Telemetro Reporta
# screen_name : TReporta
# protected : False
# verified : True
# followers_count : 622634
# friends_count : 1536
# listed_count : 1146
# favourites_count : 21213
# statuses_count : 557539
# created_at : Thu Jun 30 15:56:41 +0000 2011
#
# NO.39 user
# id : 761469053181370369
# name : CGTN en Español
# screen_name : cgtnenespanol
# protected : False
# verified : True
# followers_count : 606504
# friends_count : 144
# listed_count : 751
# favourites_count : 3327
# statuses_count : 35451
# created_at : Fri Aug 05 07:49:04 +0000 2016
#
# NO.40 user
# id : 54046888
# name : Tank
# screen_name : TheRealTank
# protected : False
# verified : True
# followers_count : 588005
# friends_count : 7704
# listed_count : 1873
# favourites_count : 108
# statuses_count : 38603
# created_at : Sun Jul 05 23:56:02 +0000 2009
#
# NO.41 user
# id : 22993014
# name : Nine News Australia
# screen_name : 9NewsAUS
# protected : False
# verified : True
# followers_count : 576752
# friends_count : 221
# listed_count : 2446
# favourites_count : 268
# statuses_count : 287813
# created_at : Thu Mar 05 22:51:02 +0000 2009
#
# NO.42 user
# id : 44489439
# name : La Razón Digital
# screen_name : LaRazon_Bolivia
# protected : False
# verified : True
# followers_count : 539175
# friends_count : 244
# listed_count : 1792
# favourites_count : 1793
# statuses_count : 273917
# created_at : Wed Jun 03 23:34:49 +0000 2009
#
# NO.43 user
# id : 244170569
# name : اليمن الآن - اجلس في البيت
# screen_name : ALyemennow
# protected : False
# verified : False
# followers_count : 503342
# friends_count : 43
# listed_count : 1420
# favourites_count : 27973
# statuses_count : 131659
# created_at : Fri Jan 28 17:36:09 +0000 2011
#
# NO.44 user
# id : 301831339
# name : La Sopa
# screen_name : lasopapuntocom
# protected : False
# verified : False
# followers_count : 482193
# friends_count : 119030
# listed_count : 716
# favourites_count : 6913
# statuses_count : 156804
# created_at : Fri May 20 04:13:12 +0000 2011
#
# NO.45 user
# id : 22019881
# name : JHU Public Health
# screen_name : JohnsHopkinsSPH
# protected : False
# verified : True
# followers_count : 476766
# friends_count : 2678
# listed_count : 5288
# favourites_count : 13906
# statuses_count : 27788
# created_at : Thu Feb 26 15:22:11 +0000 2009
#
# NO.46 user
# id : 132681657
# name : Página Siete
# screen_name : pagina_siete
# protected : False
# verified : True
# followers_count : 474921
# friends_count : 487
# listed_count : 1071
# favourites_count : 164
# statuses_count : 241166
# created_at : Tue Apr 13 22:27:54 +0000 2010
#
# NO.47 user
# id : 17347668
# name : Diario La Prensa
# screen_name : DiarioLaPrensa
# protected : False
# verified : True
# followers_count : 466517
# friends_count : 1053
# listed_count : 1951
# favourites_count : 305
# statuses_count : 369169
# created_at : Wed Nov 12 20:21:42 +0000 2008
#
# NO.48 user
# id : 19489239
# name : The Jerusalem Post
# screen_name : Jerusalem_Post
# protected : False
# verified : True
# followers_count : 464564
# friends_count : 487
# listed_count : 8867
# favourites_count : 1378
# statuses_count : 232457
# created_at : Sun Jan 25 14:17:26 +0000 2009
#
# NO.49 user
# id : 113709009
# name : Enrique Alfaro
# screen_name : EnriqueAlfaroR
# protected : False
# verified : True
# followers_count : 460219
# friends_count : 5089
# listed_count : 937
# favourites_count : 10921
# statuses_count : 31289
# created_at : Fri Feb 12 19:27:21 +0000 2010
#
# NO.50 user
# id : 80894808
# name : Radio Ñandutí
# screen_name : nanduti
# protected : False
# verified : False
# followers_count : 441404
# friends_count : 11812
# listed_count : 805
# favourites_count : 2242
# statuses_count : 247275
# created_at : Thu Oct 08 17:16:00 +0000 2009
#
# NO.51 user
# id : 2940105757
# name : سطام بن خالد ال سعود
# screen_name : sattam_al_saud
# protected : False
# verified : True
# followers_count : 438678
# friends_count : 923
# listed_count : 491
# favourites_count : 23221
# statuses_count : 27984
# created_at : Tue Dec 23 00:05:48 +0000 2014
#
# NO.52 user
# id : 1209417007
# name : Steve Scalise
# screen_name : SteveScalise
# protected : False
# verified : True
# followers_count : 415108
# friends_count : 1302
# listed_count : 2407
# favourites_count : 2017
# statuses_count : 11097
# created_at : Fri Feb 22 18:10:47 +0000 2013
#
# NO.53 user
# id : 152358615
# name : La Silla Rota
# screen_name : lasillarota
# protected : False
# verified : True
# followers_count : 406457
# friends_count : 3660
# listed_count : 3705
# favourites_count : 11749
# statuses_count : 1654667
# created_at : Sat Jun 05 18:46:31 +0000 2010
#
# NO.54 user
# id : 18185798
# name : Oneindia Tamil
# screen_name : thatsTamil
# protected : False
# verified : True
# followers_count : 400353
# friends_count : 29
# listed_count : 876
# favourites_count : 5
# statuses_count : 288985
# created_at : Wed Dec 17 09:00:53 +0000 2008
#
# NO.55 user
# id : 14135426
# name : Keith Ellison
# screen_name : keithellison
# protected : False
# verified : True
# followers_count : 364880
# friends_count : 6953
# listed_count : 5262
# favourites_count : 1490
# statuses_count : 24553
# created_at : Wed Mar 12 21:38:12 +0000 2008
#
# NO.56 user
# id : 11856142
# name : NBC News Business
# screen_name : NBCNewsBusiness
# protected : False
# verified : True
# followers_count : 361046
# friends_count : 382
# listed_count : 5683
# favourites_count : 126
# statuses_count : 39903
# created_at : Fri Jan 04 22:11:26 +0000 2008
#
# NO.57 user
# id : 6134882
# name : DW News
# screen_name : dwnews
# protected : False
# verified : True
# followers_count : 358697
# friends_count : 730
# listed_count : 6033
# favourites_count : 3293
# statuses_count : 272666
# created_at : Fri May 18 11:00:50 +0000 2007
#
# NO.58 user
# id : 17844412
# name : Vivir Guadalajara
# screen_name : VivirGDL
# protected : False
# verified : False
# followers_count : 354955
# friends_count : 9993
# listed_count : 740
# favourites_count : 21499
# statuses_count : 44435
# created_at : Wed Dec 03 18:47:11 +0000 2008
#
# NO.59 user
# id : 54739943
# name : Milenio Jalisco
# screen_name : MilenioJalisco
# protected : False
# verified : True
# followers_count : 354358
# friends_count : 792
# listed_count : 1157
# favourites_count : 362
# statuses_count : 249895
# created_at : Wed Jul 08 00:40:42 +0000 2009
#
# NO.60 user
# id : 201841968
# name : Monumental AM 1080
# screen_name : AM_1080
# protected : False
# verified : True
# followers_count : 350687
# friends_count : 203
# listed_count : 523
# favourites_count : 1238
# statuses_count : 150470
# created_at : Tue Oct 12 18:58:53 +0000 2010
#
# NO.61 user
# id : 15484198
# name : George Galloway
# screen_name : georgegalloway
# protected : False
# verified : True
# followers_count : 349318
# friends_count : 11003
# listed_count : 3294
# favourites_count : 270772
# statuses_count : 246997
# created_at : Fri Jul 18 18:08:10 +0000 2008
#
# NO.62 user
# id : 201867844
# name : Reuters Latam
# screen_name : ReutersLatam
# protected : False
# verified : True
# followers_count : 346942
# friends_count : 562
# listed_count : 3683
# favourites_count : 145
# statuses_count : 169275
# created_at : Tue Oct 12 20:12:52 +0000 2010
#
# NO.63 user
# id : 292619181
# name : scarlet monahan
# screen_name : scarletmonahan
# protected : False
# verified : False
# followers_count : 340896
# friends_count : 24417
# listed_count : 1857
# favourites_count : 540474
# statuses_count : 1900353
# created_at : Tue May 03 23:23:17 +0000 2011
#
# NO.64 user
# id : 824332206952714240
# name : Alt. Public Lands 🏜🏔🏕🌲
# screen_name : AltPublicLands
# protected : False
# verified : False
# followers_count : 323235
# friends_count : 745
# listed_count : 2640
# favourites_count : 1729
# statuses_count : 3029
# created_at : Wed Jan 25 19:04:48 +0000 2017
#
# NO.65 user
# id : 131546062
# name : Rick Scott
# screen_name : SenRickScott
# protected : False
# verified : True
# followers_count : 321769
# friends_count : 2802
# listed_count : 3790
# favourites_count : 23
# statuses_count : 16438
# created_at : Sat Apr 10 16:03:04 +0000 2010
#
# NO.66 user
# id : 34262462
# name : Sputnik
# screen_name : SputnikInt
# protected : False
# verified : True
# followers_count : 320298
# friends_count : 288
# listed_count : 7097
# favourites_count : 17
# statuses_count : 90663
# created_at : Wed Apr 22 12:55:28 +0000 2009
#
# NO.67 user
# id : 154650240
# name : Patricia Montero
# screen_name : Pattymontero_
# protected : False
# verified : False
# followers_count : 299223
# friends_count : 48
# listed_count : 590
# favourites_count : 1582
# statuses_count : 17786
# created_at : Fri Jun 11 20:56:54 +0000 2010
#
# NO.68 user
# id : 14730894
# name : FreedomWorks
# screen_name : FreedomWorks
# protected : False
# verified : True
# followers_count : 292879
# friends_count : 10607
# listed_count : 4220
# favourites_count : 21838
# statuses_count : 107749
# created_at : Sun May 11 04:29:14 +0000 2008
#
# NO.69 user
# id : 150701482
# name : LA PRENSA de Lara
# screen_name : laprensalara
# protected : False
# verified : False
# followers_count : 286219
# friends_count : 1043
# listed_count : 654
# favourites_count : 472
# statuses_count : 290765
# created_at : Tue Jun 01 16:05:21 +0000 2010
#
# NO.70 user
# id : 35203319
# name : Evan Kirstel #StayHome #RemoteWork
# screen_name : evankirstel
# protected : False
# verified : False
# followers_count : 284869
# friends_count : 268036
# listed_count : 13763
# favourites_count : 570024
# statuses_count : 919057
# created_at : Sat Apr 25 12:45:16 +0000 2009
#
# NO.71 user
# id : 38278953
# name : etcétera
# screen_name : revistaetcetera
# protected : False
# verified : True
# followers_count : 283609
# friends_count : 550
# listed_count : 2070
# favourites_count : 11382
# statuses_count : 200110
# created_at : Wed May 06 21:18:14 +0000 2009
#
# NO.72 user
# id : 76267146
# name : TNN ช่อง16
# screen_name : tnnthailand
# protected : False
# verified : True
# followers_count : 277075
# friends_count : 487
# listed_count : 448
# favourites_count : 749
# statuses_count : 234361
# created_at : Tue Sep 22 06:24:28 +0000 2009
#
# NO.73 user
# id : 197496309
# name : Frank Luntz
# screen_name : FrankLuntz
# protected : False
# verified : True
# followers_count : 275291
# friends_count : 402
# listed_count : 3750
# favourites_count : 1087
# statuses_count : 27453
# created_at : Fri Oct 01 17:14:19 +0000 2010
#
# NO.74 user
# id : 832686254873468929
# name : Diario Perú21
# screen_name : peru21noticias
# protected : False
# verified : False
# followers_count : 258208
# friends_count : 315
# listed_count : 490
# favourites_count : 2
# statuses_count : 200954
# created_at : Fri Feb 17 20:20:48 +0000 2017
#
# NO.75 user
# id : 47619730
# name : สำนักข่าว INN
# screen_name : INNNEWS
# protected : False
# verified : True
# followers_count : 241202
# friends_count : 455
# listed_count : 660
# favourites_count : 85
# statuses_count : 64887
# created_at : Tue Jun 16 13:12:40 +0000 2009
#
# NO.76 user
# id : 18167178
# name : La Provence
# screen_name : laprovence
# protected : False
# verified : True
# followers_count : 237123
# friends_count : 355
# listed_count : 2133
# favourites_count : 2099
# statuses_count : 176159
# created_at : Tue Dec 16 17:35:43 +0000 2008
#
# NO.77 user
# id : 300815030
# name : Caracol Radio Cali
# screen_name : Caracol_Cali
# protected : False
# verified : False
# followers_count : 232615
# friends_count : 37344
# listed_count : 418
# favourites_count : 869
# statuses_count : 86059
# created_at : Wed May 18 12:08:52 +0000 2011
#
# NO.78 user
# id : 111157576
# name : ecuadorenvivo
# screen_name : ecuadorenvivo
# protected : False
# verified : False
# followers_count : 224372
# friends_count : 927
# listed_count : 826
# favourites_count : 142
# statuses_count : 279989
# created_at : Thu Feb 04 00:15:53 +0000 2010
#
# NO.79 user
# id : 16894445
# name : WBTV News
# screen_name : WBTV_News
# protected : False
# verified : True
# followers_count : 219214
# friends_count : 766
# listed_count : 1449
# favourites_count : 2782
# statuses_count : 251739
# created_at : Tue Oct 21 21:33:02 +0000 2008
#
# NO.80 user
# id : 9427572
# name : Lisa Mei Crowley 🐸
# screen_name : LisaMei62
# protected : False
# verified : False
# followers_count : 211266
# friends_count : 16145
# listed_count : 1310
# favourites_count : 117078
# statuses_count : 60301
# created_at : Sat Oct 13 20:52:08 +0000 2007
#
# NO.81 user
# id : 20118767
# name : Dr. Gina
# screen_name : RealDrGina
# protected : False
# verified : True
# followers_count : 202855
# friends_count : 42106
# listed_count : 1423
# favourites_count : 53767
# statuses_count : 52007
# created_at : Thu Feb 05 03:51:40 +0000 2009
#
# NO.82 user
# id : 18193312
# name : Vanguardia
# screen_name : vanguardiamx
# protected : False
# verified : True
# followers_count : 199896
# friends_count : 15975
# listed_count : 1322
# favourites_count : 2297
# statuses_count : 334415
# created_at : Wed Dec 17 17:03:43 +0000 2008
#
# NO.83 user
# id : 25887412
# name : 10 News First
# screen_name : 10NewsFirst
# protected : False
# verified : True
# followers_count : 199847
# friends_count : 600
# listed_count : 1056
# favourites_count : 1557
# statuses_count : 104235
# created_at : Sun Mar 22 21:46:24 +0000 2009
#
# NO.84 user
# id : 22677427
# name : Michael Smerconish
# screen_name : smerconish
# protected : False
# verified : True
# followers_count : 197230
# friends_count : 2101
# listed_count : 2013
# favourites_count : 1415
# statuses_count : 23442
# created_at : Tue Mar 03 20:52:50 +0000 2009
#
# NO.85 user
# id : 16334139
# name : WBZ | CBS Boston News
# screen_name : wbz
# protected : False
# verified : True
# followers_count : 194274
# friends_count : 2791
# listed_count : 3104
# favourites_count : 517
# statuses_count : 193842
# created_at : Wed Sep 17 18:40:03 +0000 2008
#
# NO.86 user
# id : 3418695765
# name : Eiffion and porcsha 🐶🇬🇧✊🤞
# screen_name : collectibulldog
# protected : False
# verified : False
# followers_count : 191691
# friends_count : 177879
# listed_count : 2235
# favourites_count : 974208
# statuses_count : 850535
# created_at : Wed Aug 12 20:39:53 +0000 2015
#
# NO.87 user
# id : 63805938
# name : Diario Financiero
# screen_name : DFinanciero
# protected : False
# verified : True
# followers_count : 190174
# friends_count : 1489
# listed_count : 1930
# favourites_count : 794
# statuses_count : 187407
# created_at : Fri Aug 07 19:25:57 +0000 2009
#
# NO.88 user
# id : 45190383
# name : NewsBusters
# screen_name : newsbusters
# protected : False
# verified : True
# followers_count : 188071
# friends_count : 20878
# listed_count : 4122
# favourites_count : 740
# statuses_count : 132089
# created_at : Sat Jun 06 18:59:21 +0000 2009
#
# NO.89 user
# id : 1370971824
# name : Susan❤ UnitedWeStand ⭐⭐⭐
# screen_name : GaetaSusan
# protected : False
# verified : False
# followers_count : 184862
# friends_count : 72509
# listed_count : 799
# favourites_count : 145045
# statuses_count : 509544
# created_at : Mon Apr 22 01:39:07 +0000 2013
#
# NO.90 user
# id : 2820491389
# name : Will Friedle
# screen_name : willfriedle
# protected : False
# verified : True
# followers_count : 183622
# friends_count : 479
# listed_count : 541
# favourites_count : 39699
# statuses_count : 5589
# created_at : Fri Sep 19 21:01:01 +0000 2014
#
# NO.91 user
# id : 1601822730
# name : red+ noticias
# screen_name : RedMasNoticias
# protected : False
# verified : True
# followers_count : 179687
# friends_count : 571
# listed_count : 711
# favourites_count : 8437
# statuses_count : 255228
# created_at : Wed Jul 17 21:13:08 +0000 2013
#
# NO.92 user
# id : 52499738
# name : Alcaldía de Baruta
# screen_name : AlcaldiaBaruta
# protected : False
# verified : True
# followers_count : 178820
# friends_count : 27337
# listed_count : 1072
# favourites_count : 502
# statuses_count : 78822
# created_at : Tue Jun 30 19:54:17 +0000 2009
#
# NO.93 user
# id : 141303134
# name : TOYPILANEWS
# screen_name : toypilaNews
# protected : False
# verified : False
# followers_count : 171374
# friends_count : 189978
# listed_count : 357
# favourites_count : 78308
# statuses_count : 238500
# created_at : Fri May 07 18:34:39 +0000 2010
#
# NO.94 user
# id : 829735580
# name : Mike Beacham
# screen_name : Mike_Beacham
# protected : False
# verified : False
# followers_count : 171182
# friends_count : 137235
# listed_count : 855
# favourites_count : 5771
# statuses_count : 279410
# created_at : Mon Sep 17 20:14:38 +0000 2012
#
# NO.95 user
# id : 49439815
# name : Tuto Quiroga
# screen_name : tutoquiroga
# protected : False
# verified : True
# followers_count : 169049
# friends_count : 63
# listed_count : 343
# favourites_count : 52124
# statuses_count : 24486
# created_at : Sun Jun 21 21:48:47 +0000 2009
#
# NO.96 user
# id : 45931483
# name : VOA Urdu
# screen_name : URDUVOA
# protected : False
# verified : True
# followers_count : 167713
# friends_count : 844
# listed_count : 343
# favourites_count : 220
# statuses_count : 83364
# created_at : Tue Jun 09 20:13:17 +0000 2009
#
# NO.97 user
# id : 27652717
# name : FXStreet News
# screen_name : FXstreetNews
# protected : False
# verified : False
# followers_count : 167529
# friends_count : 271
# listed_count : 3145
# favourites_count : 146
# statuses_count : 344700
# created_at : Mon Mar 30 15:05:53 +0000 2009
#
# NO.98 user
# id : 415816193
# name : Min. de Comunicación
# screen_name : mincombolivia
# protected : False
# verified : True
# followers_count : 163450
# friends_count : 240
# listed_count : 553
# favourites_count : 8907
# statuses_count : 168370
# created_at : Fri Nov 18 21:17:33 +0000 2011
#
# NO.99 user
# id : 8091552
# name : El Siglo de Torreón
# screen_name : torreon
# protected : False
# verified : True
# followers_count : 163051
# friends_count : 248
# listed_count : 885
# favourites_count : 211
# statuses_count : 736357
# created_at : Thu Aug 09 23:21:55 +0000 2007
#
# NO.100 user
# id : 822462665910063105
# name : Girl♥️Bot
# screen_name : AMErikaNGIRLLL
# protected : False
# verified : False
# followers_count : 162854
# friends_count : 79367
# listed_count : 237
# favourites_count : 102879
# statuses_count : 110690
# created_at : Fri Jan 20 15:15:55 +0000 2017
#
# NO.101 user
# id : 1317821952
# name : True Laugh
# screen_name : Dailylaught
# protected : False
# verified : False
# followers_count : 160123
# friends_count : 100054
# listed_count : 430
# favourites_count : 23
# statuses_count : 20251
# created_at : Sun Mar 31 06:25:36 +0000 2013
#
# NO.102 user
# id : 90688877
# name : Milenio Edomex
# screen_name : milenio_edomex
# protected : False
# verified : False
# followers_count : 159752
# friends_count : 8651
# listed_count : 571
# favourites_count : 7
# statuses_count : 144566
# created_at : Tue Nov 17 18:35:37 +0000 2009
#
# NO.103 user
# id : 22678140
# name : Jamaica Star
# screen_name : jamaicastar
# protected : False
# verified : False
# followers_count : 158910
# friends_count : 552
# listed_count : 650
# favourites_count : 18
# statuses_count : 52054
# created_at : Tue Mar 03 20:57:02 +0000 2009
#
# NO.104 user
# id : 354582942
# name : Jeremy Scrivens
# screen_name : JeremyScrivens
# protected : False
# verified : False
# followers_count : 156237
# friends_count : 135506
# listed_count : 3604
# favourites_count : 6610
# statuses_count : 130668
# created_at : Sat Aug 13 23:47:06 +0000 2011
#
# NO.105 user
# id : 66244710
# name : Frommer's
# screen_name : Frommers
# protected : False
# verified : True
# followers_count : 153482
# friends_count : 32640
# listed_count : 2881
# favourites_count : 12963
# statuses_count : 68283
# created_at : Mon Aug 17 01:44:37 +0000 2009
#
# NO.106 user
# id : 449974837
# name : JOHN MAPPIN
# screen_name : JohnMappin
# protected : False
# verified : False
# followers_count : 152716
# friends_count : 6284
# listed_count : 64
# favourites_count : 4459
# statuses_count : 30265
# created_at : Thu Dec 29 18:31:09 +0000 2011
#
# NO.107 user
# id : 1005789878
# name : Pueblo En Línea
# screen_name : PuebloEnLnea
# protected : False
# verified : False
# followers_count : 151161
# friends_count : 1428
# listed_count : 73
# favourites_count : 80
# statuses_count : 7965
# created_at : Wed Dec 12 07:19:53 +0000 2012
#
# NO.108 user
# id : 183036128
# name : Nine News Melbourne
# screen_name : 9NewsMelb
# protected : False
# verified : True
# followers_count : 142962
# friends_count : 2326
# listed_count : 1089
# favourites_count : 1153
# statuses_count : 236422
# created_at : Thu Aug 26 00:33:14 +0000 2010
#
# NO.109 user
# id : 1391080153
# name : BTS Chile⁷
# screen_name : BTS_Chile
# protected : False
# verified : False
# followers_count : 142390
# friends_count : 271
# listed_count : 112
# favourites_count : 237
# statuses_count : 47265
# created_at : Tue Apr 30 03:34:22 +0000 2013
#
# NO.110 user
# id : 2718980845
# name : ღ Girls Outfit ღ
# screen_name : Girlscrazie
# protected : False
# verified : False
# followers_count : 140194
# friends_count : 134313
# listed_count : 324
# favourites_count : 11
# statuses_count : 446
# created_at : Sat Aug 09 09:06:28 +0000 2014
#
# NO.111 user
# id : 144678130
# name : El Día
# screen_name : Diario_ElDia
# protected : False
# verified : False
# followers_count : 138903
# friends_count : 494
# listed_count : 498
# favourites_count : 42
# statuses_count : 123919
# created_at : Mon May 17 01:08:10 +0000 2010
#
# NO.112 user
# id : 733878282337280001
# name : Story Thought's
# screen_name : StoryInWorld
# protected : False
# verified : False
# followers_count : 136848
# friends_count : 142479
# listed_count : 148
# favourites_count : 5
# statuses_count : 936
# created_at : Sat May 21 04:33:12 +0000 2016
#
# NO.113 user
# id : 16459787
# name : City Lights Books
# screen_name : CityLightsBooks
# protected : False
# verified : True
# followers_count : 131618
# friends_count : 2020
# listed_count : 2447
# favourites_count : 7857
# statuses_count : 24067
# created_at : Thu Sep 25 23:18:02 +0000 2008
#
# NO.114 user
# id : 564775911
# name : MinCultura Venezuela
# screen_name : minculturave
# protected : False
# verified : False
# followers_count : 131430
# friends_count : 1424
# listed_count : 562
# favourites_count : 31342
# statuses_count : 197599
# created_at : Fri Apr 27 15:22:36 +0000 2012
#
# NO.115 user
# id : 253020963
# name : Sputnik Mundo
# screen_name : SputnikMundo
# protected : False
# verified : True
# followers_count : 129764
# friends_count : 277
# listed_count : 1753
# favourites_count : 252
# statuses_count : 249587
# created_at : Wed Feb 16 11:49:16 +0000 2011
#
# NO.116 user
# id : 162786161
# name : Milenio Hidalgo
# screen_name : MilenioHidalgo
# protected : False
# verified : False
# followers_count : 126325
# friends_count : 94
# listed_count : 274
# favourites_count : 795
# statuses_count : 160962
# created_at : Sun Jul 04 17:38:15 +0000 2010
#
# NO.117 user
# id : 14562685
# name : R “Ray” Wang 王瑞光 JHU #MPH #PostPandemicPlaybook
# screen_name : rwang0
# protected : False
# verified : True
# followers_count : 125634
# friends_count : 94866
# listed_count : 7040
# favourites_count : 64716
# statuses_count : 298578
# created_at : Sun Apr 27 23:05:34 +0000 2008
#
# NO.118 user
# id : 227755413
# name : Michael A. Gayed, CFA
# screen_name : leadlagreport
# protected : False
# verified : True
# followers_count : 122868
# friends_count : 2673
# listed_count : 1165
# favourites_count : 16514
# statuses_count : 10038
# created_at : Fri Dec 17 18:30:45 +0000 2010
#
# NO.119 user
# id : 917586236952371201
# name : Space Theory
# screen_name : spacetheory544
# protected : False
# verified : False
# followers_count : 122665
# friends_count : 122195
# listed_count : 153
# favourites_count : 24
# statuses_count : 7294
# created_at : Tue Oct 10 03:03:01 +0000 2017
#
# NO.120 user
# id : 15678167
# name : Melissa Stewart
# screen_name : MelissaOnline
# protected : False
# verified : False
# followers_count : 121459
# friends_count : 65338
# listed_count : 4860
# favourites_count : 7463
# statuses_count : 237709
# created_at : Thu Jul 31 18:06:16 +0000 2008
#
# NO.121 user
# id : 2701987350
# name : Book Tweeps
# screen_name : BookTweepz
# protected : False
# verified : False
# followers_count : 119433
# friends_count : 117133
# listed_count : 676
# favourites_count : 1191
# statuses_count : 62462
# created_at : Sat Aug 02 23:31:01 +0000 2014
#
# NO.122 user
# id : 2596413645
# name : Carrie ❤️ America 🇺🇸 Text Trump to 88022
# screen_name : carrieksada
# protected : False
# verified : False
# followers_count : 118551
# friends_count : 33523
# listed_count : 260
# favourites_count : 280909
# statuses_count : 280844
# created_at : Tue Jun 10 00:36:13 +0000 2014
#
# NO.123 user
# id : 213589457
# name : HispanTV
# screen_name : Hispantv
# protected : False
# verified : False
# followers_count : 116493
# friends_count : 19
# listed_count : 1467
# favourites_count : 31
# statuses_count : 290487
# created_at : Tue Nov 09 09:11:18 +0000 2010
#
# NO.124 user
# id : 21901715
# name : KUTV2news
# screen_name : KUTV2News
# protected : False
# verified : True
# followers_count : 115434
# friends_count : 1000
# listed_count : 1319
# favourites_count : 4453
# statuses_count : 192704
# created_at : Wed Feb 25 18:53:36 +0000 2009
#
# NO.125 user
# id : 1131092646
# name : Nex Noticias
# screen_name : nexnoticias
# protected : False
# verified : True
# followers_count : 113099
# friends_count : 622
# listed_count : 295
# favourites_count : 2159
# statuses_count : 186501
# created_at : Tue Jan 29 13:52:48 +0000 2013
#
# NO.126 user
# id : 73299652
# name : Theo Fleury
# screen_name : TheoFleury14
# protected : False
# verified : True
# followers_count : 109999
# friends_count : 2024
# listed_count : 1367
# favourites_count : 6320
# statuses_count : 40427
# created_at : Fri Sep 11 03:32:32 +0000 2009
#
# NO.127 user
# id : 823238304183283712
# name : Dave Schreiber
# screen_name : DaveSchreiber3
# protected : False
# verified : False
# followers_count : 108990
# friends_count : 102612
# listed_count : 53
# favourites_count : 252863
# statuses_count : 294566
# created_at : Sun Jan 22 18:38:01 +0000 2017
#
# NO.128 user
# id : 137474821
# name : POLÍTICO México
# screen_name : politicomx
# protected : False
# verified : True
# followers_count : 108160
# friends_count : 914
# listed_count : 1013
# favourites_count : 736
# statuses_count : 169956
# created_at : Mon Apr 26 21:32:37 +0000 2010
#
# NO.129 user
# id : 252794509
# name : André Picard
# screen_name : picardonhealth
# protected : False
# verified : True
# followers_count : 104781
# friends_count : 1770
# listed_count : 2782
# favourites_count : 1499
# statuses_count : 129869
# created_at : Tue Feb 15 22:51:18 +0000 2011
#
# NO.130 user
# id : 34756550
# name : CHIZ 🇺🇸
# screen_name : CHIZMAGA
# protected : False
# verified : False
# followers_count : 103907
# friends_count : 90503
# listed_count : 297
# favourites_count : 202363
# statuses_count : 36832
# created_at : Thu Apr 23 22:40:57 +0000 2009
#
# NO.131 user
# id : 790019230389248000
# name : Political HEDGE
# screen_name : politicalHEDGE
# protected : False
# verified : False
# followers_count : 103181
# friends_count : 80821
# listed_count : 295
# favourites_count : 42770
# statuses_count : 832148
# created_at : Sun Oct 23 02:37:17 +0000 2016
#
# NO.132 user
# id : 2911616228
# name : Food Porn
# screen_name : itsfood_____
# protected : False
# verified : False
# followers_count : 103036
# friends_count : 1040
# listed_count : 258
# favourites_count : 50
# statuses_count : 6331
# created_at : Thu Nov 27 06:54:30 +0000 2014
#
# NO.133 user
# id : 869922954838245377
# name : IAQTeam🏵
# screen_name : IAqteam
# protected : False
# verified : False
# followers_count : 101813
# friends_count : 3829
# listed_count : 128
# favourites_count : 123546
# statuses_count : 180802
# created_at : Wed May 31 14:26:09 +0000 2017
#
# NO.134 user
# id : 103962377
# name : Milenio Tamaulipas
# screen_name : MilenioTam
# protected : False
# verified : True
# followers_count : 100326
# friends_count : 79
# listed_count : 308
# favourites_count : 55
# statuses_count : 244599
# created_at : Mon Jan 11 20:35:48 +0000 2010
#
# PostgreSQL connection is closed

# %% [markdown]
# ### 3. Find the verified user with the smallest number of followers

# %%
query_data("SELECT * FROM users WHERE verified = true ORDER BY followers_count ASC LIMIT 1", "result")
# Out:
# There are 1 querying results
#
# NO.1 user
# id : 545410392
# name : Jen Kraschnewski, MD MPH
# screen_name : jlkrasch
# protected : False
# verified : True
# followers_count : 581
# friends_count : 592
# listed_count : 9
# favourites_count : 2055
# statuses_count : 775
# created_at : Wed Apr 04 18:09:12 +0000 2012
#
# PostgreSQL connection is closed

# %% [markdown]
# ### Delete the indexes

# %%
pgsql("DROP INDEX followers_idx","index")
# Out:
# Indexes created/dropped successfully in PostgreSQL
#
# PostgreSQL connection is closed

# %%
pgsql("DROP INDEX followers_verified_idx","index")
# Out:
# Indexes created/dropped successfully in PostgreSQL
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Delete the Table

# %%
pgsql("DROP TABLE IF EXISTS users;", "drop")
# Out:
# PostgreSQL table successfully dropped
#
# PostgreSQL connection is closed

# %% [markdown]
# # MongoDB

# %% [markdown]
# # Please rememeber to put the path of file in the "with open section"

# %%
import pymongo
from pymongo import MongoClient
# you have to install mongodb using command line before using the code below

# %%
# client = MongoClient('localhost', 27017)
# db = client['twitter_db']
# collection = db['twitter_collection']
# import json
# with open("tweets", "r") as f1:
#     for line in f1:
#         try:
#             data = json.loads(line)
#             # if you want to see a specific field, you can print it. 
#             # if your file is big, there may be too many of these printed
#             # print(data['text'])
#             # insert data into MongoDB
#             collection.insert_one(data)
#         except:
#             continue
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-12a5b5de7beb> in <module>
#       3 collection = db['twitter_collection']
#       4 import json
# ----> 5 with open("tweets", "r") as f1:
#       6     for line in f1:
#       7         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tweets'

# %% [markdown]
# # Process Data in MongoDB

# %%
# import packages 
import pymongo
from pymongo import MongoClient

# Define client, db, collection
client = MongoClient('localhost', 27017)
db = client['twitter_db']
collection = db['twitter_collection']

# find one record in twitter_collection
x = collection.find_one()
# print(x)

# %%
# check how many tweets have been retweeted 
cursor = db.twitter_collection.find({"retweeted_status": {"$exists": True}})
num_of_tweets_retweeted = 0 
for doc in cursor:
    num_of_tweets_retweeted += 1
print(num_of_tweets_retweeted)
# Out:
# 15633

# %% [markdown]
# ## Create several indexes in this table for fast access
#
# If not creating indexes, it may require traversal the whole table to find the information. With index, (MongoDB stores indexes using BTree data structure), the search time complexity can be reduced a lot. (Generally, can from O(N) to O(logN))

# %%
# create a single filed index for users' followers_count to speed up the access for each single tweet based 
# on the number of their followers
collection.create_index([("user.followers_count", pymongo.DESCENDING)])

# create an index on "created_at"
collection.create_index([("created_at", pymongo.DESCENDING)])

# create an index on "retweeted_status.retweet_count"
collection.create_index([("retweeted_status.retweet_count", pymongo.DESCENDING)])

# create an index on "retweeted_status.reply_count"
collection.create_index([("retweeted_status.reply_count", pymongo.DESCENDING)])

# look at executionTimeMillis for search time, the smaller executionTimeMillis is better 
# cursor.explain()
# Out:
# 'retweeted_status.reply_count_-1'

# %% [markdown]
# ## Create another collection named "first_100_tweets_table"

# %%
# Create another collection named first_100_tweets_table
collection_2 = db['first_100_tweets_table']

# %% [markdown]
# ### The following chunk of code can only be run once, and it insert the first 100 tweets into this collection one by one

# %%
#first_100_tweets = db.twitter_collection.find().sort("created_at", -1).limit(100)
#for doc in first_100_tweets:
#    collection_2.insert_one(doc)

# %%
# find one doc in the new collection "first_100_tweets_table"
y = collection_2.find_one()
#print(y)

# %% [markdown]
# ## Make a deep copy of the first_100_tweets_table in this program, and it will be used as a in program database, which can be accessed faster than the database

# %%
# make a deep copy of the first_100_tweets_table in this program, and it can be accessed faster than the database
cache_in_program = []
cursor = db.first_100_tweets_table.find()
for doc in cursor:
    cache_in_program.append(doc)

# %% [markdown]
# ## Make some queries using MongoDB

# %%
# find the number of tweets in this database 
cursor = db.twitter_collection.find()
num_of_tweets = 0 
for doc in cursor:
    num_of_tweets += 1
print(num_of_tweets)
# Out:
# 19171

# %%
# find the content of the newest tweet
newest_tweet = db.first_100_tweets_table.find().limit(1) 
for doc in newest_tweet:
    content_of_newest_tweet = doc['text']
    print(content_of_newest_tweet)
# Out:
# RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…

# %%
# find the time of the latest tweet created in this database
newest_tweet = db.first_100_tweets_table.find().limit(1) 
for doc in newest_tweet:
    created_time_of_newest_tweet = doc['created_at']
print(created_time_of_newest_tweet)
# Out:
# Wed Apr 15 00:56:34 +0000 2020

# %%
# find the user id of the user who has the largest number of followers in this database
user_with_largest_num_of_followers = db.twitter_collection.find({}, {"user.id", "user.name", "user.followers_count"}).sort("user.followers_count", -1).limit(1)
for doc in user_with_largest_num_of_followers:
    user_id_with_largest_num_of_followers = doc['user']['id']
    user_name_with_largest_num_of_followers = doc['user']['name']
print("user id: " + str(user_id_with_largest_num_of_followers) + "\nuser name: " + user_name_with_largest_num_of_followers)
# Out:
# user id: 1115874631
# user name: CGTN

# %%
# find how many users in this database have more than 100k followers
cursor = db.twitter_collection.find({"user.followers_count": {"$gt": 100000}}, {"user.id", "user.followers_count"})
num_of_users_with_gt100k_followers = 0 
for doc in cursor:
    num_of_users_with_gt100k_followers += 1
print(num_of_users_with_gt100k_followers)
# Out:
# 167

# %%
# find the tweets with most retweets
most_retweets = db.twitter_collection.find({}, {"retweeted_status.text", "retweeted_status.retweet_count"}).sort("retweeted_status.retweet_count", -1).limit(5)
for doc in most_retweets:
    tweets_with_most_retweets = doc['retweeted_status']['text']
    print(tweets_with_most_retweets)
# Out:
# All the other countries are making the US look like it’s being ran by a moron
# All the other countries are making the US look like it’s being ran by a moron
# All the other countries are making the US look like it’s being ran by a moron
# All the other countries are making the US look like it’s being ran by a moron
# All the other countries are making the US look like it’s being ran by a moron

# %%
# find tweets made by users who are verified
verified = db.twitter_collection.find({"user.verified": {"$exists": True}})
for doc in verified:
    verified_tweets = doc['text']
    verified_tweets_name = doc['user']['name']
    #print("Name:", verified_tweets_name, "\nTweet:", verified_tweets)

# %%
# get the average character length of all the tweets
all_tweets = db.twitter_collection.find()
sum = 0
for doc in all_tweets:
    tweet = doc['text']
    sum += len(tweet)
    
average_length = sum/num_of_tweets
print("The average length of a tweet in this database is",average_length, "characters.")
# Out:
# The average length of a tweet in this database is 123.95425382087528 characters.

# %%
# find tweets with the most replies (most controversial)
most_replies = db.twitter_collection.find({}, {"retweeted_status.text", "retweeted_status.reply_count"}).sort("retweeted_status.reply_count", -1).limit(5)
for doc in most_replies:
    length_of_tweets_with_most_replies = len(doc['retweeted_status']['text'])
    print(length_of_tweets_with_most_replies)
    tweets_with_most_replies = doc['retweeted_status']['text']
    print(tweets_with_most_replies)
    print()
# Out:
# 140
# Everyone, young and old, needs to act now to slow the spread of COVID-19.  The best thing Americans can to do fight… https://t.co/t9BooCw8QS
#
# 140
# Everyone, young and old, needs to act now to slow the spread of COVID-19.  The best thing Americans can to do fight… https://t.co/t9BooCw8QS
#
# 140
# Everyone, young and old, needs to act now to slow the spread of COVID-19.  The best thing Americans can to do fight… https://t.co/t9BooCw8QS
#
# 140
# Preliminary investigations conducted by the Chinese authorities have found no clear evidence of human-to-human tran… https://t.co/1GHUbI2YXm
#
# 140
# Preliminary investigations conducted by the Chinese authorities have found no clear evidence of human-to-human tran… https://t.co/1GHUbI2YXm

# %%
# # getting tweets that are blow a certain character length
# length = 40
# all_tweets = db.twitter_collection.find({}, {"retweeted_status", "retweeted_status.text"})
# for doc in all_tweets:
#     # if tweet is less than desired length, add it
#     if (len(doc['retweeted_status']['text']) < length):
#         short_tweets = doc['retweeted_status']['text']
#         #print(short_tweets)

# %%
# find tweets from people with the most followers
most_followers = db.twitter_collection.find({}, {"user.id", "user.followers_count", "text"}).sort("user.followers_count", -1).limit(2)
for doc in most_followers:
    user_id_with_most_followers = doc['user']['id']
    follower_count = doc['user']['followers_count']
    tweets_by_most_followers = doc['text']
    tweets_from_people_with_most_followers = "User ID: " + str(user_id_with_most_followers) + "\nNumber of followers: " + str(follower_count) + "\nTweet: " + tweets_by_most_followers
    print(tweets_from_people_with_most_followers)
# Out:
# User ID: 1115874631
# Number of followers: 14024195
# Tweet: Numbers from the Chinese mainland on Tuesday: one new #COVID19 death in #Hubei; 46 new cases (36 originating abroad… https://t.co/Fw6RKZoDQf
# User ID: 37034483
# Number of followers: 12616711
# Tweet: Here's how drones helping India in fight against #coronavirus https://t.co/ATdiBectqs https://t.co/Cx6dH0Hc2O

# %% [markdown]
# ## Prepare answers to some common questions in the program which will be put into cache later

# %%
common_questions = {
    "Number of tweets in database?": num_of_tweets,
    "What is the content of the newest tweet?": content_of_newest_tweet,
    "What time is the latest tweet created in this database?": created_time_of_newest_tweet,
    "What is the user id of the user who has the largest number of followers in this database?": "user id: " + str(user_id_with_largest_num_of_followers) + "\nuser name: " + user_name_with_largest_num_of_followers,
    "What is the content of the tweet with most retweets? ": tweets_with_most_retweets,
    "How many users in this database have more than 100k followers?": num_of_users_with_gt100k_followers,
    "What is the average length of a tweet in this database?": average_length,
    "What is the tweet with most replies, and how many replies it gets?": tweets_with_most_replies + "\n" + str(length_of_tweets_with_most_replies) + " replies",
    "What is the tweet from people with most followers? ": tweets_from_people_with_most_followers
    
}

# %%
for i, val in common_questions.items():
    print(i, val)
# Out:
# Number of tweets in database? 19171
# What is the content of the newest tweet? RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…
# What time is the latest tweet created in this database? Wed Apr 15 00:56:34 +0000 2020
# What is the user id of the user who has the largest number of followers in this database? user id: 1115874631
# user name: CGTN
# What is the content of the tweet with most retweets?  All the other countries are making the US look like it’s being ran by a moron
# How many users in this database have more than 100k followers? 167
# What is the average length of a tweet in this database? 123.95425382087528
# What is the tweet with most replies, and how many replies it gets? Preliminary investigations conducted by the Chinese authorities have found no clear evidence of human-to-human tran… https://t.co/1GHUbI2YXm
# 140 replies
# What is the tweet from people with most followers?  User ID: 37034483
# Number of followers: 12616711
# Tweet: Here's how drones helping India in fight against #coronavirus https://t.co/ATdiBectqs https://t.co/Cx6dH0Hc2O

# %% [markdown]
# # LRU Cache for questions asked
# ### LRU Cache is a cache replacement algorithm that removes the least recently used data in order to make room for new data.

# %%
# LRU Cache requires the linkedlist structure, but Python does not have it, so we have to create a LinkedNode class
# key is the question, value is the answer to that question, next is the next question of this question in the cache
class LinkedNode:
    
    def __init__(self, key=None, value=None, next=None):
        self.key = key
        self.value = value
        self.next = next

# %%
# LRU Cache is a cache replacement algorithm that removes the least recently used data in order to make room for 
# new data.
class LRUCache:
    
        # This is the initial function to define 
        # Dictionary(key_to_prev): key is the question, value is the linkednode of the previous question
        # LinkedNode(dummy): the linkednode without value to point out the memory address of the linkedlist
        # tail: the tail of the linkedlist, and its initial value is dummy
        # Integer(capacity): define of the size of the cache, which is the same as the length of the linkedlist
        def __init__(self, capacity):
            self.key_to_prev = {}
            self.dummy = LinkedNode()
            self.tail = self.dummy
            self.capacity = capacity
        
        # The function push_back is to put the question node at the tail of the linkedlist
        def push_back(self, node):
            self.key_to_prev[node.key] = self.tail
            self.tail.next = node
            self.tail = node
        
        # The function pop_front is to delete the head node from the linkedlist and the next node becomes the new head
        def pop_front(self):
            head = self.dummy.next
            del self.key_to_prev[head.key]
            self.dummy.next = head.next
            self.key_to_prev[head.next.key] = self.dummy
            
        # The function kick is to move the prev node's next to the tail of the linkedlist
        def kick(self, prev): 
            node = prev.next
            if node == self.tail:
                return
        
            # remove the current node from linked list
            prev.next = node.next
            # update the previous node in hash map
            self.key_to_prev[node.next.key] = prev
            node.next = None

            self.push_back(node)
        
        # The function get is to get the value(answer) of the key(question)
        # If the question is not in the linkedlist, it will return -1, and we need go to the database to find answers
        # Else: it will return the value(answer) of the key(question)
        def get(self, key):
            if key not in self.key_to_prev:
                return -1
        
            prev = self.key_to_prev[key]
            current = prev.next
        
            self.kick(prev)
            return current.value
        
        # The function put is to put a question into the linkedlist
        def set(self, key, value):
            # If the question is in the cache, it will move the question from the original node position to the 
            # tail of the original linkedlist
            if key in self.key_to_prev:
                self.kick(self.key_to_prev[key])
                self.key_to_prev[key].next.value = value
                return
            
            # If the question is not in cache, it will be inseretd to the linkedlist
            self.push_back(LinkedNode(key, value))
            # In addition, if the cache reached its capacity, it will invaliaded the lease recently used question 
            # before inserting the new question 
            if len(self.key_to_prev) > self.capacity:
                self.pop_front()

# %% [markdown]
# ## Apply LRU Cache algorithm to cache of questions asked in this project

# %%
if __name__ == "__main__":
    # set the size of the cache be 20 questions
    LRU_Cache = LRUCache(20)

    # put several common questions into cache firstly
    for question in common_questions:
        LRU_Cache.set(question, common_questions[question])

# %%
LRU_Cache.get("Number of tweets in database?")
# Out:
# 19171

# %%
LRU_Cache.get("What is the content of the newest tweet?")
# Out:
# 'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…'

# %%
LRU_Cache.get("What is LRU Cache?")
# Out:
# -1

# %% [markdown]
# # Search Application

# %% [markdown]
# ## Initial attempt: Design a basic serach application UI with the questions and answers based on common_questions

# %%
# import some packages for user interface design 
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider

# define a function f to return the answer to the input question 
def f(Question):
    print(common_questions[Question])

# %%
# interface for user to do question search 
def search_application():
    interact(f, Question = [x for x in common_questions])
search_application()
# import timeit
# print(timeit.timeit(search_application, number=1))
# Out:
# interactive(children=(Dropdown(description='Question', options=('Number of tweets in database?', 'What is the …

# %%
# w = widgets.Dropdown(
#     options = common_questions,
#     description = 'Please pick a question:', 
#     style = style, 
#     layout = {'width': 'max-content'})
# display(w)

# %% [markdown]
# ## Check running time of the common questions for search application

# %%
def common_question_in_cache():
    print(common_questions["What is the content of the newest tweet?"])

import timeit
print(timeit.timeit(common_question_in_cache, number=1))
# Out:
# RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…
# 5.926200000061499e-05

# %%
def common_question_outof_cache():
    newest_tweet = db.first_100_tweets_table.find().limit(1) 
    for doc in newest_tweet:
        content_of_newest_tweet = doc['text']
        print(content_of_newest_tweet)
import timeit
print(timeit.timeit(common_question_outof_cache, number=1))
# Out:
# RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…
# 0.0024367979999624367

# %%
def common_question_in_cache():
    print(common_questions["Number of tweets in database?"])

import timeit
print(timeit.timeit(common_question_in_cache, number=1))
# Out:
# 19171
# 4.860399999984111e-05

# %%
def common_question_outof_cache():
    cursor = db.twitter_collection.find()
    num_of_tweets = 0 
    for doc in cursor:
        num_of_tweets += 1
    print(num_of_tweets)
import timeit
print(timeit.timeit(common_question_outof_cache, number=1))
# Out:
# 19171
# 3.3622609230001217

# %% [markdown]
# ## Improvement on Search Application based on LRU Cache and More Questions

# %%
import pandas as pd
import numpy as np

# %%
# NewTweet is to find the created_time, user_id, user_name and content of newest tweets
class NewTweet:
    
    def __init__(self, number):
        self.number = number
    
    def find_tweet_content(self):
        newest_tweet = db.first_100_tweets_table.find().limit(self.number)
        index = 1
        result = []
        for doc in newest_tweet:
            temp = []
            content = doc['text']
            created_time = doc['created_at']
            user_id = doc['user']['id']
            user_name = doc['user']['name']
            temp.append("No. " + str(index))
            temp.append(created_time + " User ID: " + str(user_id) + " User Name: " + user_name)
            temp.append(content_of_newest_tweet)
            result.append(temp)
            index += 1
        return result

# FamousUsers is to find the user_id, user_name and number_of_followers of users with most followers
class FamousUsers:
    def __init__(self, number):
        self.number = number
    
    def find_famous_users(self):
        # find the user id of the user who has the largest number of followers in this database
        user_with_largest_num_of_followers = db.twitter_collection.find({}, {"user.id", "user.name", "user.followers_count"}).sort("user.followers_count", -1).limit(self.number)
        index = 1
        result = []
        for doc in user_with_largest_num_of_followers:
            temp = []
            user_id = doc['user']['id']
            user_name = doc['user']['name']
            number_of_followers = doc['user']['followers_count']
            temp.append("No. " + str(index))
            temp.append("User ID: " + str(user_id) + "\nUser Name: " + user_name + "\nFollowers: " + str(number_of_followers))
            result.append(temp)
            index += 1
        return result

            
from collections import Counter
# PopularWords is to find words which have been used most in this dataset
class PopularWords:
    def __init__(self, number):
        self.number = number
    
    def find_popular_words(self):
        sentences = db.twitter_collection.find({}, {"text"})
        word_dictionary = {}
        for doc in sentences:
            sentence = doc['text']
            for word in sentence.split():
                if word in word_dictionary:
                    word_dictionary[word] += 1
                else:
                    word_dictionary[word] = 1
        k = Counter(word_dictionary)
        high = k.most_common(self.number)
        index = 1
        result = []
        for word in high:
            temp = []
            temp.append("No. " + str(index))
            temp.append(word[0] + ": " + str(word[1]))
            result.append(temp)
            index += 1
        return result

# TweetsFromFamousUsers is to find tweets from people with the most followers
class TweetsFromFamousUsers:
    def __init__(self, number):
        self.number = number
        
    def find_tweets_from_famous_users(self):
        most_followers = db.twitter_collection.find({}, {"user.id", "user.followers_count", "text"}).sort("user.followers_count", -1).limit(self.number)
        index = 1
        result = []
        for doc in most_followers:
            user_id = doc['user']['id']
            follower_count = doc['user']['followers_count']
            tweet = doc['text']
            tweets_from_famous_users = "User ID: " + str(user_id) + "\nNumber of Followers: " + str(follower_count) + "\nTweet: " + tweet
            temp = []
            temp.append("No. " + str(index))
            temp.append(tweets_from_famous_users)
            result.append(temp)
            index += 1
        return result

# ValidQuestion is to find the question to its related query 
class ValidQuestion:
    
    def __init__(self, question, number):
        self.question = question
        self.number = number
    
    def get_question(self):
        if self.question == "Find Newest Tweets":
            new_tweet = NewTweet(self.number)
            return new_tweet.find_tweet_content()
        
        elif self.question == "Find Famous Users":
            famous_users = FamousUsers(self.number)
            return famous_users.find_famous_users()

        elif self.question == "Find popular words":
            popular_words = PopularWords(self.number)
            return popular_words.find_popular_words()
        
        elif self.question == "Find tweets from famous users":
            tweets_from_famous_users = TweetsFromFamousUsers(self.number)
            return tweets_from_famous_users.find_tweets_from_famous_users()
        
        else:
            print("We don't have this question in search application!")
            return

# %%
import ipywidgets as widgets
dropdown_count = widgets.Dropdown(options = [x for x in range(100)])

# %%
def dropdown_count(change):
    valid_question 
    display(df_london[df_london.year == change.new])

# %%
valid_question = ValidQuestion("Find Newest Tweets", 5)
valid_question.get_question()
# Out:
# [['No. 1',
#   'Wed Apr 15 00:56:34 +0000 2020 User ID: 22091137 User Name: Basu Ghosh Das',
#   'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…'],
#  ['No. 2',
#   'Wed Apr 15 00:56:34 +0000 2020 User ID: 531629036 User Name: Creeds Cannon',
#   'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…'],
#  ['No. 3',
#   'Wed Apr 15 00:56:34 +0000 2020 User ID: 1042203452212948992 User Name: christy��️\u200d��',
#   'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…'],
#  ['No. 4',
#   'Wed Apr 15 00:56:34 +0000 2020 User ID: 3551287573 User Name: david lee',
#   'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…'],
#  ['No. 5',
#   'Wed Apr 15 00:56:33 +0000 2020 User ID: 3100647275 User Name: eegeeb',
#   'RT @TarekFatah: Pakistanis in Karachi defying orders not to congregate in mosques by creating makeshift mosques on rooftops. Working hard t…']]

# %%
# from IPython.display import display
class SearchApplicationOne:
    def __init__(self, capacity):
        self.LRU_Cache = LRUCache(capacity)
    
    def user_interface(self):
        @interact(options = widgets.Dropdown(options=['Find Newest Tweets', 'Find Famous Users', 'Find popular words', 
                                              'Find tweets from famous users'],
            value='Find Newest Tweets',
            description='Question:',
            disabled=False), 
            Top = widgets.IntSlider(min = 1, max = 100, step = 1, description = "Top: ", value = 1))

        def f(options, Top):
            if self.LRU_Cache.get((options, Top)) != -1:
                answers = self.LRU_Cache.get((options, Top))
                for answer in answers:
                    for val in answer:
                        print(val)
                    print()
                    
            else:
                valid_question = ValidQuestion(options, Top)
                answers = valid_question.get_question()
                self.LRU_Cache.set((options, Top), answers)
                for answer in answers:
                    for val in answer:
                        print(val)
                    print()
            print(self.LRU_Cache.key_to_prev)

# %%
serach_appliaction = SearchApplicationOne(10)
serach_appliaction.user_interface()
# Out:
# interactive(children=(Dropdown(description='Question:', options=('Find Newest Tweets', 'Find Famous Users', 'F…
